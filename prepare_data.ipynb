# %%
# !pip install scikit-learn pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/athipse/.local/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: pandas in /home/athipse/.local/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/athipse/.local/lib/python3.12/site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in /home/athipse/.local/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /home/athipse/.local/lib/python3.12/site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/athipse/.local/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
PROJECT_ID = "mlops-week-1-499905"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# %%
! gsutil mb -l {LOCATION} -p {PROJECT_ID} gs://iris-training-data-bucket
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Creating gs://iris-training-data-bucket/...
# ServiceException: 409 A Cloud Storage bucket named 'iris-training-data-bucket' already exists. Try another name. Bucket names must be globally unique across all Google Cloud projects, including those outside of your organization.

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

data = pd.read_csv('data/iris.csv')

extra = data.sample(20, random_state=42)

data = pd.concat([data, extra])

data.to_csv("data/iris.csv", index=False)

train, test = train_test_split(data, test_size = 0.4, stratify = data['species'], random_state = 42)

train.to_csv("iris_train.csv", index=False)
test.to_csv("iris_eval.csv", index=False)

print("Train:", train.shape)
print("Eval:", test.shape)
# Out:
# Train: (102, 5)
# Eval: (68, 5)

# %%
! gsutil cp iris_train.csv gs://iris-training-data-bucket/
! gsutil cp iris_eval.csv gs://iris-training-data-bucket/
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying file://iris_train.csv [Content-Type=text/csv]...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying file://iris_eval.csv [Content-Type=text/csv]...
# / [1 files][  1.7 KiB/  1.7 KiB]
# Operation completed over 1 objects/1.7 KiB.
